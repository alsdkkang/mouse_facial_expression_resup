# %%
import deeplabcut 
import pandas as pd
import numpy as np

from pathlib import Path

phase = 3
deeplabcut_project = Path('../data/dlc/mouse_face-telfer-2023-06-27').resolve()
assert deeplabcut_project.exists()

# %%
deeplabcut.analyze_time_lapse_frames(
    deeplabcut_project / 'config.yaml',
    deeplabcut_project / f'labeled-data/phase{phase}')
# Out:
# Using snapshot-206000 for model /home/andre/repos/mouse-facial-expressions-2023/data/dlc/mouse_face-telfer-2023-06-27/dlc-models/iteration-0/mouse_faceJun27-trainset95shuffle1
# /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 2023-06-29 09:32:26.245352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 09:32:26.245796: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.245857: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.245894: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.245927: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.245961: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.245991: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.246023: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.246053: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-06-29 09:32:26.246057: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-29 09:32:26.277891: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 09:32:26.300142: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Analyzing all frames in the directory:  /home/andre/repos/mouse-facial-expressions-2023/data/dlc/mouse_face-telfer-2023-06-27/labeled-data/phase3
# Starting to extract posture
# Overall # of frames:  2879  found with (before cropping) frame dimensions:  1920 1200
#   0%|          | 0/2879 [00:00<?, ?it/s]2023-06-29 09:32:27.229315: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-29 09:32:27.498453: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-29 09:32:27.737701: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-29 09:32:28.275205: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-29 09:32:28.960121: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 589824000 exceeds 10% of free system memory.
#   1%|          | 28/2879 [00:24<41:26,  1.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 # deeplabcut.analyze_time_lapse_frames(
#       2 #     deeplabcut_project / 'config.yaml',
#       3 #     deeplabcut_project / 'labeled-data/phase2')
# ----> 5 deeplabcut.analyze_time_lapse_frames(
#       6     deeplabcut_project / 'config.yaml',
#       7     deeplabcut_project / 'labeled-data/phase3')
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/predict_videos.py:1403, in analyze_time_lapse_frames(config, directory, frametype, shuffle, trainingsetindex, gputouse, save_as_csv, modelprefix)
#    1400 if nframes > 0:
#    1401     start = time.time()
# -> 1403     PredictedData, nframes, nx, ny = GetPosesofFrames(
#    1404         cfg,
#    1405         dlc_cfg,
#    1406         sess,
#    1407         inputs,
#    1408         outputs,
#    1409         directory,
#    1410         framelist,
#    1411         nframes,
#    1412         dlc_cfg["batch_size"],
#    1413     )
#    1414     stop = time.time()
#    1416     if cfg["cropping"] == True:
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/predict_videos.py:1215, in GetPosesofFrames(cfg, dlc_cfg, sess, inputs, outputs, directory, framelist, nframes, batchsize)
#    1212     frames[batch_ind] = img_as_ubyte(im)
#    1214 if batch_ind == batchsize - 1:
# -> 1215     pose = predict.getposeNP(frames, dlc_cfg, sess, inputs, outputs)
#    1216     PredictedData[
#    1217         batch_num * batchsize : (batch_num + 1) * batchsize, :
#    1218     ] = pose
#    1219     batch_ind = 0
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/core/predict.py:168, in getposeNP(image, cfg, sess, inputs, outputs, outall)
#     164 """Adapted from DeeperCut, performs numpy-based faster inference on batches.
#     165 Introduced in https://www.biorxiv.org/content/10.1101/457242v1"""
#     167 num_outputs = cfg.get("num_outputs", 1)
# --> 168 outputs_np = sess.run(outputs, feed_dict={inputs: image})
#     170 scmap, locref = extract_cnn_outputmulti(outputs_np, cfg)  # processes image batch.
#     171 batchsize, ny, nx, num_joints = scmap.shape
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:968, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     965 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     967 try:
# --> 968   result = self._run(None, fetches, feed_dict, options_ptr,
#     969                      run_metadata_ptr)
#     970   if run_metadata:
#     971     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:1191, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188 # We only want to really perform the run if fetches or targets are provided,
#    1189 # or if the call is a partial run that specifies feeds.
#    1190 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1191   results = self._do_run(handle, final_targets, final_fetches,
#    1192                          feed_dict_tensor, options, run_metadata)
#    1193 else:
#    1194   results = []
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:1371, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1368   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1370 if handle is None:
# -> 1371   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1372                        run_metadata)
#    1373 else:
#    1374   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:1378, in BaseSession._do_call(self, fn, *args)
#    1376 def _do_call(self, fn, *args):
#    1377   try:
# -> 1378     return fn(*args)
#    1379   except errors.OpError as e:
#    1380     message = compat.as_text(e.message)
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:1361, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1359   # Ensure any changes to the graph are reflected in the runtime.
#    1360   self._extend_graph()
# -> 1361   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1362                                   target_list, run_metadata)
#
# File ~/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/client/session.py:1454, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1452 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1453                         run_metadata):
# -> 1454   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1455                                           fetch_list, target_list,
#    1456                                           run_metadata)
#
# KeyboardInterrupt:

# %%
reference_labels = pd.read_hdf(deeplabcut_project / 'labeled-data/phase1/CollectedData_telfer.h5')
reference_labels.head(3)
# Out:
# scorer                                                         telfer  \
# bodyparts                                                        nose
# coords                                                              x
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  1186.087065
#                     f16_rec1_preinjection_frame00860.png  1139.049649
#                     f16_rec1_preinjection_frame01267.png  1127.612055
#
# scorer                                                                 \
# bodyparts
# coords                                                              y
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  1077.416405
#                     f16_rec1_preinjection_frame00860.png  1010.139741
#                     f16_rec1_preinjection_frame01267.png  1005.546201
#
# scorer                                                                 \
# bodyparts                                                    left_eye
# coords                                                              x
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  1254.215157
#                     f16_rec1_preinjection_frame00860.png  1225.577404
#                     f16_rec1_preinjection_frame01267.png  1224.002151
#
# scorer                                                                \
# bodyparts
# coords                                                             y
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  973.864915
#                     f16_rec1_preinjection_frame00860.png  935.973094
#                     f16_rec1_preinjection_frame01267.png  919.483615
#
# scorer                                                                 \
# bodyparts                                                    left_ear
# coords                                                              x
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  1329.494136
#                     f16_rec1_preinjection_frame00860.png  1322.218883
#                     f16_rec1_preinjection_frame01267.png  1296.294723
#
# scorer                                                                \
# bodyparts
# coords                                                             y
# labeled-data phase1 f16_rec1_preinjection_frame00769.png  867.200479
#                     f16_rec1_preinjection_frame00860.png  864.624258
#                     f16_rec1_preinjection_frame01267.png  859.813556
#
# scorer                                                                  \
# bodyparts                                                right_eye
# coords                                                           x   y
# labeled-data phase1 f16_rec1_preinjection_frame00769.png       NaN NaN
#                     f16_rec1_preinjection_frame00860.png       NaN NaN
#                     f16_rec1_preinjection_frame01267.png       NaN NaN
#
# scorer
# bodyparts                                                right_ear
# coords                                                           x   y
# labeled-data phase1 f16_rec1_preinjection_frame00769.png       NaN NaN
#                     f16_rec1_preinjection_frame00860.png       NaN NaN
#                     f16_rec1_preinjection_frame01267.png       NaN NaN

# %%
dlc_file = next(deeplabcut_project.glob(f'labeled-data/phase{phase}/*DLC*.h5'))
generated_labels = pd.read_hdf(dlc_file)
generated_labels.head(3)
# Out:
# scorer                              DLC_resnet50_mouse_faceJun27shuffle1_515000  \
# bodyparts                                                                  nose
# coords                                                                        x
# f10_rec0_acclimation_frame02732.png                                  749.382997
# f10_rec0_acclimation_frame09225.png                                 1296.585223
# f10_rec0_acclimation_frame09845.png                                 1191.332633
#
# scorer                                                                    \
# bodyparts                                                       left_eye
# coords                                         y likelihood            x
# f10_rec0_acclimation_frame02732.png  1095.405515   0.996296   710.081069
# f10_rec0_acclimation_frame09225.png   866.442637   0.864383  1295.949001
# f10_rec0_acclimation_frame09845.png   698.983784   0.455974  1167.809329
#
# scorer                                                                   \
# bodyparts                                                      left_ear
# coords                                        y likelihood            x
# f10_rec0_acclimation_frame02732.png  987.912323   0.632406   804.152322
# f10_rec0_acclimation_frame09225.png  788.173750   0.021008  1254.692934
# f10_rec0_acclimation_frame09845.png  670.641397   0.033081  1150.827604
#
# scorer                                                                   \
# bodyparts                                                     right_eye
# coords                                        y likelihood            x
# f10_rec0_acclimation_frame02732.png  872.148126   0.951151   710.983781
# f10_rec0_acclimation_frame09225.png  735.796854   0.004170  1297.024435
# f10_rec0_acclimation_frame09845.png  671.308063   0.003914  1169.133311
#
# scorer                                                                   \
# bodyparts                                                     right_ear
# coords                                        y likelihood            x
# f10_rec0_acclimation_frame02732.png  989.145429   0.976487   672.369849
# f10_rec0_acclimation_frame09225.png  788.369126   0.998573  1261.710619
# f10_rec0_acclimation_frame09845.png  670.709612   0.982741  1140.141500
#
# scorer
# bodyparts
# coords                                        y likelihood
# f10_rec0_acclimation_frame02732.png  881.352836   0.999103
# f10_rec0_acclimation_frame09225.png  736.936956   0.999496
# f10_rec0_acclimation_frame09845.png  673.152557   0.999843

# %%
images = generated_labels.index

index = pd.MultiIndex.from_tuples(('labeled-data', f'phase{phase}', l) for l in images)
columns = pd.MultiIndex.from_tuples(
    [('telfer',b,c) for s,b,c in generated_labels.columns],
    names=['scorer', 'bodyparts', 'coords']
)

reshaped_df = generated_labels.copy()
reshaped_df = reshaped_df.set_index(index)
reshaped_df.columns = columns
reshaped_df.head(3)
# Out:
# scorer                                                        telfer  \
# bodyparts                                                       nose
# coords                                                             x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   749.382997
#                     f10_rec0_acclimation_frame09225.png  1296.585223
#                     f10_rec0_acclimation_frame09845.png  1191.332633
#
# scorer                                                                \
# bodyparts
# coords                                                             y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png  1095.405515
#                     f10_rec0_acclimation_frame09225.png   866.442637
#                     f10_rec0_acclimation_frame09845.png   698.983784
#
# scorer                                                              \
# bodyparts
# coords                                                  likelihood
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   0.996296
#                     f10_rec0_acclimation_frame09225.png   0.864383
#                     f10_rec0_acclimation_frame09845.png   0.455974
#
# scorer                                                                \
# bodyparts                                                   left_eye
# coords                                                             x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   710.081069
#                     f10_rec0_acclimation_frame09225.png  1295.949001
#                     f10_rec0_acclimation_frame09845.png  1167.809329
#
# scorer                                                               \
# bodyparts
# coords                                                            y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png  987.912323
#                     f10_rec0_acclimation_frame09225.png  788.173750
#                     f10_rec0_acclimation_frame09845.png  670.641397
#
# scorer                                                              \
# bodyparts
# coords                                                  likelihood
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   0.632406
#                     f10_rec0_acclimation_frame09225.png   0.021008
#                     f10_rec0_acclimation_frame09845.png   0.033081
#
# scorer                                                                \
# bodyparts                                                   left_ear
# coords                                                             x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   804.152322
#                     f10_rec0_acclimation_frame09225.png  1254.692934
#                     f10_rec0_acclimation_frame09845.png  1150.827604
#
# scorer                                                               \
# bodyparts
# coords                                                            y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png  872.148126
#                     f10_rec0_acclimation_frame09225.png  735.796854
#                     f10_rec0_acclimation_frame09845.png  671.308063
#
# scorer                                                              \
# bodyparts
# coords                                                  likelihood
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   0.951151
#                     f10_rec0_acclimation_frame09225.png   0.004170
#                     f10_rec0_acclimation_frame09845.png   0.003914
#
# scorer                                                                \
# bodyparts                                                  right_eye
# coords                                                             x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   710.983781
#                     f10_rec0_acclimation_frame09225.png  1297.024435
#                     f10_rec0_acclimation_frame09845.png  1169.133311
#
# scorer                                                               \
# bodyparts
# coords                                                            y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png  989.145429
#                     f10_rec0_acclimation_frame09225.png  788.369126
#                     f10_rec0_acclimation_frame09845.png  670.709612
#
# scorer                                                              \
# bodyparts
# coords                                                  likelihood
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   0.976487
#                     f10_rec0_acclimation_frame09225.png   0.998573
#                     f10_rec0_acclimation_frame09845.png   0.982741
#
# scorer                                                                \
# bodyparts                                                  right_ear
# coords                                                             x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png   672.369849
#                     f10_rec0_acclimation_frame09225.png  1261.710619
#                     f10_rec0_acclimation_frame09845.png  1140.141500
#
# scorer
# bodyparts
# coords                                                            y likelihood
# labeled-data phase3 f10_rec0_acclimation_frame02732.png  881.352836   0.999103
#                     f10_rec0_acclimation_frame09225.png  736.936956   0.999496
#                     f10_rec0_acclimation_frame09845.png  673.152557   0.999843

# %% [markdown]
# ### Identify when left-right confusion occurs and filter lower confidence points

# %%
counter = 0
for idx, row in reshaped_df.iterrows():
    pairs = [
        ['left_ear', 'right_ear'],
        ['left_eye', 'right_eye']
    ]

    threshold = 5
    for bp1, bp2 in pairs:
        x1, y1, c1 = row.loc[:, bp1, ['x', 'y', 'likelihood']]
        x2, y2, c2 = row.loc[:, bp2, ['x', 'y', 'likelihood']]
        distance = np.sqrt((x2-x1)**2 + (y2-y1)**2)
        
        if distance is not np.nan and distance < 5:
            if c1 > c2:
                reshaped_df.loc[idx, pd.IndexSlice[:,bp2,:]] = np.nan
            elif c2 > c1:
                reshaped_df.loc[idx, pd.IndexSlice[:,bp1,:]] = np.nan
            
            counter += 1
            
        
print(counter)
# Out:
# 0

# %%
likelihood = reshaped_df.xs('likelihood', level='coords', axis=1)
confident_labels = reshaped_df.where(likelihood > 0.6)
images = confident_labels.index
confident_labels = confident_labels.drop(columns='likelihood', level='coords')
confident_labels
# Out:
# scorer                                                            telfer  \
# bodyparts                                                           nose
# coords                                                                 x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png       749.382997
#                     f10_rec0_acclimation_frame09225.png      1296.585223
#                     f10_rec0_acclimation_frame09845.png              NaN
#                     f10_rec0_acclimation_frame10799.png       951.613413
#                     f10_rec0_acclimation_frame13123.png       461.215053
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png  1094.163603
#                     m9_rec4_4h-postinjection_frame14598.png  1115.760052
#                     m9_rec4_4h-postinjection_frame15926.png  1109.595499
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png  1196.747857
#
# scorer                                                                    \
# bodyparts
# coords                                                                 y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png      1095.405515
#                     f10_rec0_acclimation_frame09225.png       866.442637
#                     f10_rec0_acclimation_frame09845.png              NaN
#                     f10_rec0_acclimation_frame10799.png      1059.435143
#                     f10_rec0_acclimation_frame13123.png      1083.396232
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png  1050.399803
#                     m9_rec4_4h-postinjection_frame14598.png  1070.264444
#                     m9_rec4_4h-postinjection_frame15926.png  1065.433989
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png  1058.272410
#
# scorer                                                                    \
# bodyparts                                                       left_eye
# coords                                                                 x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png              NaN
#                     f10_rec0_acclimation_frame09225.png              NaN
#                     f10_rec0_acclimation_frame09845.png              NaN
#                     f10_rec0_acclimation_frame10799.png       835.042796
#                     f10_rec0_acclimation_frame13123.png       522.911936
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png  1097.688960
#                     m9_rec4_4h-postinjection_frame14598.png  1119.386667
#                     m9_rec4_4h-postinjection_frame15926.png  1114.399463
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png          NaN
#
# scorer                                                                    \
# bodyparts
# coords                                                                 y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png              NaN
#                     f10_rec0_acclimation_frame09225.png              NaN
#                     f10_rec0_acclimation_frame09845.png              NaN
#                     f10_rec0_acclimation_frame10799.png      1015.265196
#                     f10_rec0_acclimation_frame13123.png       988.988084
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png   982.327700
#                     m9_rec4_4h-postinjection_frame14598.png   992.352808
#                     m9_rec4_4h-postinjection_frame15926.png   992.537699
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png          NaN
#
# scorer                                                                    \
# bodyparts                                                       left_ear
# coords                                                                 x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png       804.152322
#                     f10_rec0_acclimation_frame09225.png              NaN
#                     f10_rec0_acclimation_frame09845.png              NaN
#                     f10_rec0_acclimation_frame10799.png       890.021919
#                     f10_rec0_acclimation_frame13123.png       598.734677
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png  1133.342103
#                     m9_rec4_4h-postinjection_frame14598.png  1154.286886
#                     m9_rec4_4h-postinjection_frame15926.png  1147.391659
#                     m9_rec4_4h-postinjection_frame19682.png  1168.986835
#                     m9_rec4_4h-postinjection_frame24242.png  1185.158275
#
# scorer                                                                   \
# bodyparts
# coords                                                                y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png      872.148126
#                     f10_rec0_acclimation_frame09225.png             NaN
#                     f10_rec0_acclimation_frame09845.png             NaN
#                     f10_rec0_acclimation_frame10799.png      868.132409
#                     f10_rec0_acclimation_frame13123.png      922.999229
# ...                                                                 ...
#                     m9_rec4_4h-postinjection_frame13126.png  942.198995
#                     m9_rec4_4h-postinjection_frame14598.png  939.276219
#                     m9_rec4_4h-postinjection_frame15926.png  944.605915
#                     m9_rec4_4h-postinjection_frame19682.png  931.689891
#                     m9_rec4_4h-postinjection_frame24242.png  917.434900
#
# scorer                                                                    \
# bodyparts                                                      right_eye
# coords                                                                 x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png       710.983781
#                     f10_rec0_acclimation_frame09225.png      1297.024435
#                     f10_rec0_acclimation_frame09845.png      1169.133311
#                     f10_rec0_acclimation_frame10799.png       919.707193
#                     f10_rec0_acclimation_frame13123.png              NaN
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png          NaN
#                     m9_rec4_4h-postinjection_frame14598.png          NaN
#                     m9_rec4_4h-postinjection_frame15926.png          NaN
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png          NaN
#
# scorer                                                                   \
# bodyparts
# coords                                                                y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png      989.145429
#                     f10_rec0_acclimation_frame09225.png      788.369126
#                     f10_rec0_acclimation_frame09845.png      670.709612
#                     f10_rec0_acclimation_frame10799.png      963.801978
#                     f10_rec0_acclimation_frame13123.png             NaN
# ...                                                                 ...
#                     m9_rec4_4h-postinjection_frame13126.png         NaN
#                     m9_rec4_4h-postinjection_frame14598.png         NaN
#                     m9_rec4_4h-postinjection_frame15926.png         NaN
#                     m9_rec4_4h-postinjection_frame19682.png         NaN
#                     m9_rec4_4h-postinjection_frame24242.png         NaN
#
# scorer                                                                    \
# bodyparts                                                      right_ear
# coords                                                                 x
# labeled-data phase3 f10_rec0_acclimation_frame02732.png       672.369849
#                     f10_rec0_acclimation_frame09225.png      1261.710619
#                     f10_rec0_acclimation_frame09845.png      1140.141500
#                     f10_rec0_acclimation_frame10799.png       762.555264
#                     f10_rec0_acclimation_frame13123.png              NaN
# ...                                                                  ...
#                     m9_rec4_4h-postinjection_frame13126.png          NaN
#                     m9_rec4_4h-postinjection_frame14598.png          NaN
#                     m9_rec4_4h-postinjection_frame15926.png          NaN
#                     m9_rec4_4h-postinjection_frame19682.png          NaN
#                     m9_rec4_4h-postinjection_frame24242.png          NaN
#
# scorer
# bodyparts
# coords                                                                y
# labeled-data phase3 f10_rec0_acclimation_frame02732.png      881.352836
#                     f10_rec0_acclimation_frame09225.png      736.936956
#                     f10_rec0_acclimation_frame09845.png      673.152557
#                     f10_rec0_acclimation_frame10799.png      930.272797
#                     f10_rec0_acclimation_frame13123.png             NaN
# ...                                                                 ...
#                     m9_rec4_4h-postinjection_frame13126.png         NaN
#                     m9_rec4_4h-postinjection_frame14598.png         NaN
#                     m9_rec4_4h-postinjection_frame15926.png         NaN
#                     m9_rec4_4h-postinjection_frame19682.png         NaN
#                     m9_rec4_4h-postinjection_frame24242.png         NaN
#
# [2879 rows x 10 columns]

# %%
confident_labels.to_hdf(deeplabcut_project / f'labeled-data/phase{phase}/CollectedData_telfer.h5', '/keypoints')
confident_labels.to_csv(deeplabcut_project / f'labeled-data/phase{phase}/CollectedData_telfer.csv')

# %% [markdown]
# ## Apply Trained Model to Videos Test

# %%
videos_dir = Path("../data/raw/")
videos = list(map(str, videos_dir.glob('*.mp4')))

deeplabcut.analyze_videos(
    deeplabcut_project / 'config.yaml',
    videos,
    destfolder=Path("../data/raw/")
)
# Out:
# Using snapshot-1030000 for model /home/andre/repos/mouse-facial-expressions-2023/data/dlc/mouse_face-telfer-2023-06-27/dlc-models/iteration-2/mouse_faceJun27-trainset95shuffle1
# /home/andre/miniconda3/envs/mfe/lib/python3.10/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  ../data/raw/placeholder.mp4
# Loading  ../data/raw/placeholder.mp4
# Duration of video [s]:  3.0 , recorded with  40.0 fps!
# Overall # of frames:  120  found with (before cropping) frame dimensions:  1920 1200
# Starting to extract posture
#   0%|          | 0/120 [00:00<?, ?it/s]2023-06-30 17:30:55.026935: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-30 17:30:55.306254: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-30 17:30:55.542903: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-30 17:30:56.082350: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1179648000 exceeds 10% of free system memory.
# 2023-06-30 17:30:56.768288: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 589824000 exceeds 10% of free system memory.
# 100%|██████████| 120/120 [01:58<00:00,  1.01it/s]
# Saving results in ../data/raw...
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# 'DLC_resnet50_mouse_faceJun27shuffle1_1030000'
